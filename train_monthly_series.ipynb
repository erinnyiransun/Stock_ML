# %% [markdown]
# <a href="https://colab.research.google.com/github/atlantiquesun/Stock_ML/blob/main/train_monthly_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import preprocessing
import datetime
from dateutil.relativedelta import relativedelta
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt

# %%
def prepare_train_data_series(last_company_index, train_start_month, train_window, sample_window, lag=1):
  '''
  input:
  start_month: the earliest month used in training
  train_start_month: the first day of the first month in this train set
  train_end_month: the first day of the last month in this train set

  return:
  X_train: (samples, timesteps, features)

  currently no time lag
  '''
  train_end_month = train_start_month + relativedelta(months=train_window-1)
  X_train = []
  y_train = []
  trade_tic = []

  companies = pd.read_csv("/content/drive/MyDrive/StockML /Data/companyInfo/companies_final.csv")

  for i in range(companies.shape[0]):
    if(i > last_company_index):break
    company = companies.at[i, 'githubUser']
    ticker = companies.at[i, 'symbol'].upper()

    raw = pd.read_csv("/content/drive/MyDrive/StockML /Data/processedData/cumulativeData/"+company+".csv")
    raw = raw.drop('Unnamed: 0', axis=1)

    #group GitHub data into months
    raw.date = pd.to_datetime(raw['date'])
    df = raw.groupby(pd.Grouper(key="date", freq="M")).sum()
    df['month_end'] = df.index
    df['month_start'] = df['month_end'] + datetime.timedelta(days=1)
    df['month_start'] = df['month_start'].shift(1)
    df[features_column] = df[features_column].shift(lag) #lag GitHub data
    df = df.dropna()
    scaler = MinMaxScaler()
    df[features_column] = scaler.fit_transform(df[features_column])

    #select the data within the current train window
    df = df.loc[(df.month_start >= train_start_month) & (df.month_start <= train_end_month)] 

    #group stock data into months then select the last datum in a month to calculate monthly return
    stock_data = pd.read_csv("/content/drive/MyDrive/StockML /Data/financialData/"+ticker+".csv")
    stock_data['Date'] = pd.to_datetime(stock_data['Date'])
    stock_data = stock_data.groupby(pd.Grouper(key="Date", freq="M")).nth([-1]) #index are month-ends
    stock_data['Date'] = stock_data.index
    stock_data['last_close'] = stock_data.Close.shift(1)
    stock_data['monthly_return'] = (stock_data.Close / stock_data.last_close)-1
    stock_data = stock_data.dropna()

    #the first (sample_window - 1) month do not need to have stock data, so we can pad stock_df
    pad_index = []
    for t in range(1, sample_window):
      pad_index.append(((list(stock_data["Date"])[0]+relativedelta(days=1)) - relativedelta(months=t))-relativedelta(days=1)) 
    stock_pad = pd.DataFrame(index=pad_index, columns=stock_data.columns)
    stock_pad['Date'] = stock_pad.index
    stock_data = pd.concat([stock_pad, stock_data])

    #select the data within the current train window
    stock_df = stock_data.loc[(stock_data.Date >= train_start_month) & (stock_data.Date < (train_end_month+relativedelta(months=1)))]

    #some months may not have stock data
    df = df.loc[df['month_end'].isin(list(stock_df['Date']))]
    #print("check if two are the same:", df.shape, stock_df.shape, list(df['month_end'])[0], list(stock_df['Date'])[0], list(df['month_end'])[-1], list(stock_df['Date'])[-1])

    df_X = df[features_column]
    df_y = stock_df['monthly_return']
    
    if(df.shape[0] < sample_window):
      continue
    else:
      trade_tic.append(ticker)
      for j in range(df.shape[0]-sample_window+1):
        X_train.append(df_X.values[j:j+sample_window, :])
        y_train.append(df_y.values[j+sample_window-1])
    
  X_train = np.asarray(X_train)
  y_train = np.asarray(y_train)
  
  return (X_train, y_train, trade_tic)

# %% [markdown]
# # Model

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.linear_model import Ridge

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.model_selection import TimeSeriesSplit, GridSearchCV,RandomizedSearchCV

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

def train_lstm(X_train, y_train, n_features=1):
    
    # Initialising the RNN
    regressor = Sequential()
    # Adding the first LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = 80, return_sequences = True, input_shape = (X_train.shape[1], n_features)))
    regressor.add(Dropout(0.2))

    # Adding a second LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = 40, return_sequences = True))
    regressor.add(Dropout(0.2))

    # Adding a third LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = 20, return_sequences = False))
    regressor.add(Dropout(0.2))

    # Adding a fourth LSTM layer and some Dropout regularisation
    #regressor.add(LSTM(units = 20,return_sequences = False))
    #regressor.add(Dropout(0.2))

    # Adding the output layer
    regressor.add(Dense(units = 1, activation='tanh'))
    
    #scoring_method = 'neg_mean_absolute_error'
    # scoring_method = 'neg_mean_squared_error'
    #scoring_method = 'neg_mean_squared_log_error'
    # Compiling the RNN
    regressor.compile(optimizer = 'adam', loss = 'mean_absolute_error')

    # Fitting the RNN to the Training set
    regressor.fit(X_train, y_train, epochs = 4, batch_size = 64)
    return regressor



def evaluate_model(model, X_test, y_test):
    from sklearn.metrics import mean_squared_error
    #from sklearn.metrics import mean_squared_log_error

    from sklearn.metrics import mean_absolute_error
    from sklearn.metrics import explained_variance_score
    from sklearn.metrics import r2_score
    y_predict = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_predict)
    

    mse = mean_squared_error(y_test, y_predict)
    #msle = mean_squared_log_error(y_test, y_predict)

    explained_variance = explained_variance_score(y_test, y_predict)
    r2 = r2_score(y_test, y_predict)

    return mae



def append_return_table(df_predict, unique_datetime, y_trade_return, trade_tic, current_index):
    tmp_table = pd.DataFrame(columns=trade_tic)
    tmp_table = tmp_table.append(pd.Series(y_trade_return, index=trade_tic), ignore_index=True)
    df_predict.loc[unique_datetime[current_index]] = tmp_table.loc[0]

# %% [markdown]
# # Training

# %%
last_company_index = 17
start_month=pd.to_datetime("2010-01-01")
train_window = 36
test_window = 9
sample_window = 6
features_column = ['star', 'fork', 'issue', 'commit', 'issueClosed', 'pullRequest', 'pullRequestClosed', 'pullRequestMerged']

train_start_months = []
for i in range(0, 90):
  train_start_months.append(start_month+relativedelta(months=i))
print(train_start_months[-1], train_start_months[-1]+relativedelta(months=train_window-1), train_start_months[-1]+relativedelta(months=train_window))

#prepare trade month_start info
unique_datetime = [x+relativedelta(months=train_window+test_window) for x in train_start_months]
companies = pd.read_csv("/content/drive/MyDrive/StockML /Data/companyInfo/companies_final.csv")
unique_ticker = list(companies["symbol"])


df_predict_lr = pd.DataFrame(columns=unique_ticker, index=unique_datetime)
df_predict_lasso = pd.DataFrame(columns=unique_ticker, index=unique_datetime)
df_predict_ridge = pd.DataFrame(columns=unique_ticker, index=unique_datetime)
df_predict_rf = pd.DataFrame(columns=unique_ticker, index=unique_datetime)
df_predict_svm= pd.DataFrame(columns=unique_ticker, index=unique_datetime)
#df_predict_gbm = pd.DataFrame(columns=unique_ticker, index=unique_datetime)
#df_predict_ada = pd.DataFrame(columns=unique_ticker, index=unique_datetime)
df_predict_lstm = pd.DataFrame(columns=unique_ticker, index=unique_datetime)

df_predict_best = pd.DataFrame(columns=unique_ticker, index=unique_datetime)
df_best_model_name = pd.DataFrame(columns=['model_name'], index=unique_datetime)
evaluation_record = []

for i in range(len(unique_datetime)):
  #e.g. train_start_month = 2010-01-01, train_end_month=2012-12-01
  #test_start_month = 2013-01-01, test_end_month=2013-09-01
  #trade_month = 2013-10-01 (unique_datetime[i]), will use data from 2013-05-01

  test_start_month = train_start_months[i] + relativedelta(months=train_window)
  trade_data_start_month = unique_datetime[i] + relativedelta(months= (1-sample_window))

  X_train, y_train, _ = prepare_train_data_series(last_company_index, train_start_months[i], train_window, sample_window)
  print("train:", X_train.shape, y_train.shape)

  X_test, y_test, _ = prepare_train_data_series(last_company_index, test_start_month, test_window, sample_window)
  print("test:", X_test.shape, y_test.shape)

  X_trade, y_trade, trade_tic = prepare_train_data_series(last_company_index, trade_data_start_month, sample_window, sample_window)
  print("trade:", X_trade.shape, y_trade.shape)

  lstm_model = train_lstm(X_train, y_train, len(features_column))
  lstm_eval = evaluate_model(lstm_model, X_test, y_test)

  y_trade_lstm = lstm_model.predict(X_trade).flatten()
  append_return_table(df_predict_lstm, unique_datetime, y_trade_lstm, trade_tic, current_index=i)

  print("Trade month:", unique_datetime[i] )
# Out:
# 2017-06-01 00:00:00 2020-05-01 00:00:00 2020-06-01 00:00:00
# train: (188, 6, 8) (188,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# test: (28, 6, 8) (28,)
# trade: (7, 6, 8) (7,)
# Epoch 1/4
# 3/3 [==============================] - 6s 20ms/step - loss: 0.0848
# Epoch 2/4
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0810
# Epoch 3/4
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0831
# Epoch 4/4
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0841
# Trade month: 2013-10-01 00:00:00
# train: (189, 6, 8) (189,)
# test: (28, 6, 8) (28,)
# trade: (7, 6, 8) (7,)
# Epoch 1/4
# 3/3 [==============================] - 6s 18ms/step - loss: 0.0940
# Epoch 2/4
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0907
# Epoch 3/4
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0888
# Epoch 4/4
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0885
# Trade month: 2013-11-01 00:00:00
# train: (190, 6, 8) (190,)
# test: (28, 6, 8) (28,)
# trade: (8, 6, 8) (8,)
# Epoch 1/4
# 3/3 [==============================] - 6s 19ms/step - loss: 0.0877
# Epoch 2/4
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0843
# Epoch 3/4
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0902
# Epoch 4/4
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0831
# Trade month: 2013-12-01 00:00:00
# train: (191, 6, 8) (191,)
# test: (29, 6, 8) (29,)
# trade: (8, 6, 8) (8,)
# Epoch 1/4
# 3/3 [==============================] - 7s 20ms/step - loss: 0.0849
# Epoch 2/4
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0844
# Epoch 3/4
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0838
# Epoch 4/4
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0860
# Trade month: 2014-01-01 00:00:00
# train: (192, 6, 8) (192,)
# test: (30, 6, 8) (30,)
# trade: (8, 6, 8) (8,)
# Epoch 1/4
# 3/3 [==============================] - 5s 15ms/step - loss: 0.0782
# Epoch 2/4
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0795
# Epoch 3/4
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0853
# Epoch 4/4
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0785
# Trade month: 2014-02-01 00:00:00
# train: (193, 6, 8) (193,)
# test: (31, 6, 8) (31,)
# trade: (8, 6, 8) (8,)
# Epoch 1/4
# 4/4 [==============================] - 6s 15ms/step - loss: 0.0786
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0836
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0787
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0840
# Trade month: 2014-03-01 00:00:00
# train: (194, 6, 8) (194,)
# test: (32, 6, 8) (32,)
# trade: (8, 6, 8) (8,)
# Epoch 1/4
# 4/4 [==============================] - 6s 16ms/step - loss: 0.0840
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0785
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0826
# Epoch 4/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0810
# Trade month: 2014-04-01 00:00:00
# train: (195, 6, 8) (195,)
# test: (32, 6, 8) (32,)
# trade: (8, 6, 8) (8,)
# Epoch 1/4
# 4/4 [==============================] - 7s 18ms/step - loss: 0.0879
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0779
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0772
# Epoch 4/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0804
# Trade month: 2014-05-01 00:00:00
# train: (196, 6, 8) (196,)
# test: (32, 6, 8) (32,)
# trade: (9, 6, 8) (9,)
# Epoch 1/4
# 4/4 [==============================] - 7s 18ms/step - loss: 0.0783
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0764
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0776
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0820
# Trade month: 2014-06-01 00:00:00
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# train: (197, 6, 8) (197,)
# test: (33, 6, 8) (33,)
# trade: (9, 6, 8) (9,)
# Epoch 1/4
# 4/4 [==============================] - 7s 17ms/step - loss: 0.0797
# Epoch 2/4
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0827
# Epoch 3/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0862
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0867
# Trade month: 2014-07-01 00:00:00
# train: (198, 6, 8) (198,)
# test: (34, 6, 8) (34,)
# trade: (9, 6, 8) (9,)
# Epoch 1/4
# 4/4 [==============================] - 6s 15ms/step - loss: 0.0855
# Epoch 2/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0838
# Epoch 3/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0794
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0817
# Trade month: 2014-08-01 00:00:00
# train: (199, 6, 8) (199,)
# test: (35, 6, 8) (35,)
# trade: (9, 6, 8) (9,)
# Epoch 1/4
# 4/4 [==============================] - 6s 15ms/step - loss: 0.0883
# Epoch 2/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0784
# Epoch 3/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0778
# Epoch 4/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0856
# Trade month: 2014-09-01 00:00:00
# train: (201, 6, 8) (201,)
# test: (36, 6, 8) (36,)
# trade: (9, 6, 8) (9,)
# Epoch 1/4
# 4/4 [==============================] - 7s 20ms/step - loss: 0.0878
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0849
# Epoch 3/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0812
# Epoch 4/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0809
# Trade month: 2014-10-01 00:00:00
# train: (203, 6, 8) (203,)
# test: (36, 6, 8) (36,)
# trade: (10, 6, 8) (10,)
# Epoch 1/4
# 4/4 [==============================] - 6s 16ms/step - loss: 0.0865
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0860
# Epoch 3/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0837
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0833
# Trade month: 2014-11-01 00:00:00
# train: (205, 6, 8) (205,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# test: (37, 6, 8) (37,)
# trade: (10, 6, 8) (10,)
# Epoch 1/4
# 4/4 [==============================] - 6s 16ms/step - loss: 0.0826
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0831
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0812
# Epoch 4/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0825
# Trade month: 2014-12-01 00:00:00
# train: (207, 6, 8) (207,)
# test: (38, 6, 8) (38,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# trade: (10, 6, 8) (10,)
# Epoch 1/4
# 4/4 [==============================] - 6s 15ms/step - loss: 0.0825
# Epoch 2/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0856
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0834
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0858
# Trade month: 2015-01-01 00:00:00
# train: (209, 6, 8) (209,)
# test: (39, 6, 8) (39,)
# trade: (10, 6, 8) (10,)
# Epoch 1/4
# 4/4 [==============================] - 7s 16ms/step - loss: 0.0842
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0768
# Epoch 3/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0849
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0886
# Trade month: 2015-02-01 00:00:00
# train: (211, 6, 8) (211,)
# test: (40, 6, 8) (40,)
# trade: (10, 6, 8) (10,)
# Epoch 1/4
# 4/4 [==============================] - 7s 18ms/step - loss: 0.0828
# Epoch 2/4
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0791
# Epoch 3/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0789
# Epoch 4/4
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0783
# Trade month: 2015-03-01 00:00:00
# train: (214, 6, 8) (214,)
# test: (40, 6, 8) (40,)
# trade: (10, 6, 8) (10,)
# Epoch 1/4
# 4/4 [==============================] - 7s 18ms/step - loss: 0.0822
# Epoch 2/4
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0747
# Epoch 3/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0760
# Epoch 4/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0768
# Trade month: 2015-04-01 00:00:00
# train: (217, 6, 8) (217,)
# test: (40, 6, 8) (40,)
# trade: (10, 6, 8) (10,)
# Epoch 1/4
# 4/4 [==============================] - 6s 16ms/step - loss: 0.0812
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0782
# Epoch 3/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0860
# Epoch 4/4
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0769
# Trade month: 2015-05-01 00:00:00
# train: (220, 6, 8) (220,)
# test: (40, 6, 8) (40,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 7s 16ms/step - loss: 0.0813
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0779
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0782
# Epoch 4/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0737
# Trade month: 2015-06-01 00:00:00
# train: (223, 6, 8) (223,)
# test: (41, 6, 8) (41,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 7s 19ms/step - loss: 0.0798
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0783
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0742
# Epoch 4/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0797
# Trade month: 2015-07-01 00:00:00
# train: (226, 6, 8) (226,)
# test: (42, 6, 8) (42,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 6s 17ms/step - loss: 0.0807
# Epoch 2/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0732
# Epoch 3/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0811
# Epoch 4/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0770
# Trade month: 2015-08-01 00:00:00
# train: (230, 6, 8) (230,)
# test: (43, 6, 8) (43,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 6s 19ms/step - loss: 0.0813
# Epoch 2/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0793
# Epoch 3/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0741
# Epoch 4/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0820
# Trade month: 2015-09-01 00:00:00
# train: (234, 6, 8) (234,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 7s 19ms/step - loss: 0.0737
# Epoch 2/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0764
# Epoch 3/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0754
# Epoch 4/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0794
# Trade month: 2015-10-01 00:00:00
# train: (238, 6, 8) (238,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 7s 18ms/step - loss: 0.0768
# Epoch 2/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0798
# Epoch 3/4
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0765
# Epoch 4/4
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0748
# Trade month: 2015-11-01 00:00:00
# train: (242, 6, 8) (242,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 6s 19ms/step - loss: 0.0776
# Epoch 2/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0650
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0806
# Epoch 4/4
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0772
# Trade month: 2015-12-01 00:00:00
# train: (246, 6, 8) (246,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 6s 17ms/step - loss: 0.0732
# Epoch 2/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0799
# Epoch 3/4
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0745
# Epoch 4/4
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0783
# Trade month: 2016-01-01 00:00:00
# train: (250, 6, 8) (250,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 7s 20ms/step - loss: 0.0763
# Epoch 2/4
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0781
# Epoch 3/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0815
# Epoch 4/4
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0772
# Trade month: 2016-02-01 00:00:00
# train: (254, 6, 8) (254,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 4/4 [==============================] - 6s 18ms/step - loss: 0.0772
# Epoch 2/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0805
# Epoch 3/4
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0741
# Epoch 4/4
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0748
# Trade month: 2016-03-01 00:00:00
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# train: (258, 6, 8) (258,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 6s 19ms/step - loss: 0.0749
# Epoch 2/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0790
# Epoch 3/4
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0788
# Epoch 4/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0746
# Trade month: 2016-04-01 00:00:00
# train: (262, 6, 8) (262,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 7s 23ms/step - loss: 0.0816
# Epoch 2/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0757
# Epoch 3/4
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0788
# Epoch 4/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0814
# Trade month: 2016-05-01 00:00:00
# train: (266, 6, 8) (266,)
# test: (44, 6, 8) (44,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 8s 23ms/step - loss: 0.0802
# Epoch 2/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0808
# Epoch 3/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0874
# Epoch 4/4
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0828
# Trade month: 2016-06-01 00:00:00
# train: (270, 6, 8) (270,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 7s 18ms/step - loss: 0.0799
# Epoch 2/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0787
# Epoch 3/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0835
# Epoch 4/4
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0785
# Trade month: 2016-07-01 00:00:00
# train: (274, 6, 8) (274,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 7s 18ms/step - loss: 0.0830
# Epoch 2/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0803
# Epoch 3/4
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0775
# Epoch 4/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0773
# Trade month: 2016-08-01 00:00:00
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# train: (278, 6, 8) (278,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 6s 17ms/step - loss: 0.0825
# Epoch 2/4
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0836
# Epoch 3/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0819
# Epoch 4/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0845
# Trade month: 2016-09-01 00:00:00
# train: (282, 6, 8) (282,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 6s 18ms/step - loss: 0.0880
# Epoch 2/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0832
# Epoch 3/4
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0796
# Epoch 4/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0846
# Trade month: 2016-10-01 00:00:00
# train: (286, 6, 8) (286,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 6s 17ms/step - loss: 0.0845
# Epoch 2/4
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0891
# Epoch 3/4
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0825
# Epoch 4/4
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0877
# Trade month: 2016-11-01 00:00:00
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# train: (290, 6, 8) (290,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 7s 17ms/step - loss: 0.0831
# Epoch 2/4
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0841
# Epoch 3/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0848
# Epoch 4/4
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0819
# Trade month: 2016-12-01 00:00:00
# train: (294, 6, 8) (294,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 6s 23ms/step - loss: 0.0898
# Epoch 2/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0846
# Epoch 3/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0835
# Epoch 4/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0817
# Trade month: 2017-01-01 00:00:00
# train: (298, 6, 8) (298,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 6s 24ms/step - loss: 0.0850
# Epoch 2/4
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0909
# Epoch 3/4
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0858
# Epoch 4/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0866
# Trade month: 2017-02-01 00:00:00
# train: (302, 6, 8) (302,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 6s 17ms/step - loss: 0.0848
# Epoch 2/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0804
# Epoch 3/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0790
# Epoch 4/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0916
# Trade month: 2017-03-01 00:00:00
# train: (306, 6, 8) (306,)
# test: (44, 6, 8) (44,)
# trade: (11, 6, 8) (11,)
# Epoch 1/4
# 5/5 [==============================] - 7s 18ms/step - loss: 0.0825
# Epoch 2/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0776
# Epoch 3/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0804
# Epoch 4/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0842
# Trade month: 2017-04-01 00:00:00
# train: (309, 6, 8) (309,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# test: (44, 6, 8) (44,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 5/5 [==============================] - 7s 21ms/step - loss: 0.0865
# Epoch 2/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0826
# Epoch 3/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0864
# Epoch 4/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0805
# Trade month: 2017-05-01 00:00:00
# train: (312, 6, 8) (312,)
# test: (45, 6, 8) (45,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 5/5 [==============================] - 7s 20ms/step - loss: 0.0895
# Epoch 2/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0860
# Epoch 3/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0875
# Epoch 4/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0828
# Trade month: 2017-06-01 00:00:00
# train: (315, 6, 8) (315,)
# test: (46, 6, 8) (46,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 5/5 [==============================] - 7s 19ms/step - loss: 0.0859
# Epoch 2/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0847
# Epoch 3/4
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0827
# Epoch 4/4
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0861
# Trade month: 2017-07-01 00:00:00
# train: (318, 6, 8) (318,)
# test: (47, 6, 8) (47,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 5/5 [==============================] - 8s 19ms/step - loss: 0.0802
# Epoch 2/4
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0846
# Epoch 3/4
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0838
# Epoch 4/4
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0818
# Trade month: 2017-08-01 00:00:00
# train: (321, 6, 8) (321,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 7s 16ms/step - loss: 0.0829
# Epoch 2/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0902
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0844
# Epoch 4/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0881
# Trade month: 2017-09-01 00:00:00
# train: (324, 6, 8) (324,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 16ms/step - loss: 0.0818
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0756
# Epoch 3/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0844
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0787
# Trade month: 2017-10-01 00:00:00
# train: (326, 6, 8) (326,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 16ms/step - loss: 0.0798
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0862
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0818
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0839
# Trade month: 2017-11-01 00:00:00
# train: (328, 6, 8) (328,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0785
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0904
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0838
# Epoch 4/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0854
# Trade month: 2017-12-01 00:00:00
# train: (330, 6, 8) (330,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0901
# Epoch 2/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0803
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0831
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0821
# Trade month: 2018-01-01 00:00:00
# train: (332, 6, 8) (332,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 16ms/step - loss: 0.0861
# Epoch 2/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0790
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0796
# Epoch 4/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0833
# Trade month: 2018-02-01 00:00:00
# train: (335, 6, 8) (335,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 16ms/step - loss: 0.0845
# Epoch 2/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0840
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0801
# Epoch 4/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0812
# Trade month: 2018-03-01 00:00:00
# train: (337, 6, 8) (337,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0829
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0794
# Epoch 3/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0811
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0777
# Trade month: 2018-04-01 00:00:00
# train: (339, 6, 8) (339,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0863
# Epoch 2/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0853
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0761
# Epoch 4/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0850
# Trade month: 2018-05-01 00:00:00
# train: (341, 6, 8) (341,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0829
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0771
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0755
# Epoch 4/4
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0786
# Trade month: 2018-06-01 00:00:00
# train: (343, 6, 8) (343,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0808
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0803
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0793
# Epoch 4/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0788
# Trade month: 2018-07-01 00:00:00
# train: (345, 6, 8) (345,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 6s 19ms/step - loss: 0.0753
# Epoch 2/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0774
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0844
# Epoch 4/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0756
# Trade month: 2018-08-01 00:00:00
# train: (347, 6, 8) (347,)
# test: (48, 6, 8) (48,)
# trade: (12, 6, 8) (12,)
# Epoch 1/4
# 6/6 [==============================] - 7s 18ms/step - loss: 0.0876
# Epoch 2/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0826
# Epoch 3/4
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0786
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0785
# Trade month: 2018-09-01 00:00:00
# train: (349, 6, 8) (349,)
# test: (48, 6, 8) (48,)
# trade: (13, 6, 8) (13,)
# Epoch 1/4
# 6/6 [==============================] - 7s 22ms/step - loss: 0.0830
# Epoch 2/4
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0799
# Epoch 3/4
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0788
# Epoch 4/4
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0763
# Trade month: 2018-10-01 00:00:00
# train: (350, 6, 8) (350,)
# test: (49, 6, 8) (49,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# trade: (14, 6, 8) (14,)
# Epoch 1/4
# 6/6 [==============================] - 6s 18ms/step - loss: 0.0808
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0790
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0778
# Epoch 4/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0799
# Trade month: 2018-11-01 00:00:00
# train: (351, 6, 8) (351,)
# test: (51, 6, 8) (51,)
# trade: (14, 6, 8) (14,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0787
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0814
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0764
# Epoch 4/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0827
# Trade month: 2018-12-01 00:00:00
# train: (352, 6, 8) (352,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# test: (53, 6, 8) (53,)
# trade: (14, 6, 8) (14,)
# Epoch 1/4
# 6/6 [==============================] - 6s 18ms/step - loss: 0.0738
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0784
# Epoch 3/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0792
# Epoch 4/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0760
# Trade month: 2019-01-01 00:00:00
# train: (353, 6, 8) (353,)
# test: (55, 6, 8) (55,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# trade: (14, 6, 8) (14,)
# Epoch 1/4
# 6/6 [==============================] - 7s 18ms/step - loss: 0.0837
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0740
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0734
# Epoch 4/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0756
# Trade month: 2019-02-01 00:00:00
# train: (354, 6, 8) (354,)
# test: (56, 6, 8) (56,)
# trade: (14, 6, 8) (14,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0711
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0695
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0705
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0732
# Trade month: 2019-03-01 00:00:00
# train: (355, 6, 8) (355,)
# test: (56, 6, 8) (56,)
# trade: (14, 6, 8) (14,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0765
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0749
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0724
# Epoch 4/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0694
# Trade month: 2019-04-01 00:00:00
# train: (356, 6, 8) (356,)
# test: (56, 6, 8) (56,)
# trade: (15, 6, 8) (15,)
# Epoch 1/4
# 6/6 [==============================] - 6s 17ms/step - loss: 0.0744
# Epoch 2/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0776
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0738
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0761
# Trade month: 2019-05-01 00:00:00
# train: (357, 6, 8) (357,)
# test: (57, 6, 8) (57,)
# trade: (15, 6, 8) (15,)
# Epoch 1/4
# 6/6 [==============================] - 7s 18ms/step - loss: 0.0691
# Epoch 2/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0705
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0741
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0691
# Trade month: 2019-06-01 00:00:00
# train: (358, 6, 8) (358,)
# test: (58, 6, 8) (58,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 7s 18ms/step - loss: 0.0725
# Epoch 2/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0671
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0674
# Epoch 4/4
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0685
# Trade month: 2019-07-01 00:00:00
# train: (360, 6, 8) (360,)
# test: (61, 6, 8) (61,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 6s 18ms/step - loss: 0.0828
# Epoch 2/4
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0745
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0704
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0754
# Trade month: 2019-08-01 00:00:00
# train: (363, 6, 8) (363,)
# test: (64, 6, 8) (64,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 6s 19ms/step - loss: 0.0704
# Epoch 2/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0733
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0722
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0673
# Trade month: 2019-09-01 00:00:00
# train: (366, 6, 8) (366,)
# test: (66, 6, 8) (66,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 6s 18ms/step - loss: 0.0807
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0764
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0763
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0761
# Trade month: 2019-10-01 00:00:00
# train: (369, 6, 8) (369,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 8s 26ms/step - loss: 0.0780
# Epoch 2/4
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0733
# Epoch 3/4
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0820
# Epoch 4/4
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0789
# Trade month: 2019-11-01 00:00:00
# train: (372, 6, 8) (372,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 9s 19ms/step - loss: 0.0817
# Epoch 2/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0768
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0692
# Epoch 4/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0772
# Trade month: 2019-12-01 00:00:00
# train: (375, 6, 8) (375,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 6s 19ms/step - loss: 0.0718
# Epoch 2/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0767
# Epoch 3/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0733
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0735
# Trade month: 2020-01-01 00:00:00
# train: (378, 6, 8) (378,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 7s 19ms/step - loss: 0.0846
# Epoch 2/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0760
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0789
# Epoch 4/4
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0762
# Trade month: 2020-02-01 00:00:00
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# train: (382, 6, 8) (382,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 6/6 [==============================] - 7s 17ms/step - loss: 0.0806
# Epoch 2/4
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0813
# Epoch 3/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0791
# Epoch 4/4
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0746
# Trade month: 2020-03-01 00:00:00
# train: (386, 6, 8) (386,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 6s 16ms/step - loss: 0.0782
# Epoch 2/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0751
# Epoch 3/4
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0763
# Epoch 4/4
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0740
# Trade month: 2020-04-01 00:00:00
# train: (392, 6, 8) (392,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 6s 16ms/step - loss: 0.0784
# Epoch 2/4
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0791
# Epoch 3/4
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0807
# Epoch 4/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0755
# Trade month: 2020-05-01 00:00:00
# train: (398, 6, 8) (398,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 6s 16ms/step - loss: 0.0849
# Epoch 2/4
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0758
# Epoch 3/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0797
# Epoch 4/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0774
# Trade month: 2020-06-01 00:00:00
# train: (404, 6, 8) (404,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 7s 17ms/step - loss: 0.0853
# Epoch 2/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0837
# Epoch 3/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0800
# Epoch 4/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0796
# Trade month: 2020-07-01 00:00:00
# train: (410, 6, 8) (410,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 7s 18ms/step - loss: 0.0835
# Epoch 2/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0869
# Epoch 3/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0804
# Epoch 4/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0825
# Trade month: 2020-08-01 00:00:00
# train: (416, 6, 8) (416,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 6s 19ms/step - loss: 0.0827
# Epoch 2/4
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0790
# Epoch 3/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0835
# Epoch 4/4
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0820
# Trade month: 2020-09-01 00:00:00
# train: (421, 6, 8) (421,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 6s 19ms/step - loss: 0.0866
# Epoch 2/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0837
# Epoch 3/4
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0833
# Epoch 4/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0806
# Trade month: 2020-10-01 00:00:00
# train: (426, 6, 8) (426,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 7s 19ms/step - loss: 0.0886
# Epoch 2/4
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0784
# Epoch 3/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0781
# Epoch 4/4
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0750
# Trade month: 2020-11-01 00:00:00
# train: (431, 6, 8) (431,)
# test: (68, 6, 8) (68,)
# trade: (17, 6, 8) (17,)
# Epoch 1/4
# 7/7 [==============================] - 7s 16ms/step - loss: 0.0872
# Epoch 2/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0809
# Epoch 3/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0823
# Epoch 4/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0827
# Trade month: 2020-12-01 00:00:00
# train: (436, 6, 8) (436,)
# test: (68, 6, 8) (68,)
# trade: (18, 6, 8) (18,)
# Epoch 1/4
# 7/7 [==============================] - 7s 19ms/step - loss: 0.0842
# Epoch 2/4
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0832
# Epoch 3/4
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0869
# Epoch 4/4
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0836
# Trade month: 2021-01-01 00:00:00
# train: (441, 6, 8) (441,)
# test: (69, 6, 8) (69,)
# trade: (18, 6, 8) (18,)
# Epoch 1/4
# 7/7 [==============================] - 7s 21ms/step - loss: 0.0961
# Epoch 2/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0928
# Epoch 3/4
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0888
# Epoch 4/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0892
# Trade month: 2021-02-01 00:00:00
# train: (446, 6, 8) (446,)
# test: (70, 6, 8) (70,)
# trade: (18, 6, 8) (18,)
# Epoch 1/4
# 7/7 [==============================] - 7s 17ms/step - loss: 0.0966
# Epoch 2/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1009
# Epoch 3/4
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0971
# Epoch 4/4
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0964
# Trade month: 2021-03-01 00:00:00

# %% [markdown]
# # Visualisation

# %%
def show_single_stock_accuracy(df_predict, unique_datetime, ticker):
  from matplotlib import pyplot
  prediction = df_predict[ticker]

  stock_data = pd.read_csv("/content/drive/MyDrive/StockML /Data/financialData/"+ticker+".csv")
  stock_data['Date'] = pd.to_datetime(stock_data['Date'])
  stock_data = stock_data.groupby(pd.Grouper(key="Date", freq="M")).nth([-1]) #index are month-ends
  stock_data['Date'] = stock_data.index
  stock_data['last_close'] = stock_data.Close.shift(1)
  stock_data['monthly_return'] = (stock_data.Close / stock_data.last_close)-1
  stock_data = stock_data.loc[(stock_data["Date"] >= unique_datetime[0]) & (stock_data["Date"] < (unique_datetime[-1]+relativedelta(months=1)))]


  actual = list(stock_data["monthly_return"])
  prediction = list(df_predict[ticker].dropna())
  df_predict.to_csv("/content/drive/MyDrive/StockML /Data/prediction_shop.csv")
  
  pred = pd.DataFrame(index=list(range(len(actual))), columns = ["monthly_return"])
  act = pd.DataFrame(index=list(range(len(actual))), columns = ["monthly_return"])

  pred["monthly_return"] = prediction
  act["monthly_return"] = actual
  pred.plot()
  plt.show()
  act.plot()
  plt.show()

# %%
show_single_stock_accuracy(df_predict_lstm, unique_datetime, "SHOP")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-9f016fa62992> in <module>()
# ----> 1 show_single_stock_accuracy(df_predict_lstm, unique_datetime, "SHOP")
#
# <ipython-input-39-75d0386e8187> in show_single_stock_accuracy(df_predict, unique_datetime, ticker)
#      19   act = pd.DataFrame(index=list(range(len(actual))), columns = ["monthly_return"])
#      20
# ---> 21   pred["monthly_return"] = prediction
#      22   act["monthly_return"] = actual
#      23   pred.plot()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (66) does not match length of index (71)
